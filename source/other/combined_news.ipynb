# %%
import pandas as pd

path_1 = "..//..//data//fake_news_template.csv"
path_2 = "..//..//data//fake_news_dataset.csv"

df_1 = pd.read_csv(path_1)
df_1
# Out:
#                                                   title  \
# 0     Київ ризикує залишитись без води: "Київводокан...
# 1     Ексклюзив: МОН розглядає можливість запровадже...
# 2     Угорщина знову блокує допомогу Україні: Орбан ...
# 3     За крок до прірви: Угорщина блокує критично ва...
# 4     Медична реформа дала збій: на Київщині зафіксо...
# ...                                                 ...
# 3007  Зрада чи допомога? США зволікають з поставками...
# 3008  Офіс Президента ініціює перевірку законності ф...
# 3009  Українські вчені знайшли спосіб очистити Дніпр...
# 3010  Через затримку з поставками європейського обла...
# 3011  «Заберіть у дітей останнє!»: Освітня реформа в...
#
#                                                    text
# 0     У Києві назріває масштабна криза водопостачанн...
# 1     Інформація про можливе запровадження обов'язко...
# 2     Будапешт знову став на заваді виділенню чергов...
# 3     Брюссель, Бельгія – На тлі загострення ситуаці...
# 4     На Київщині, у Васильківському районі, зафіксо...
# ...                                                 ...
# 3007  Вашингтон знову затягує рішення про передачу У...
# 3008  В Офісі Президента України розпочато службове ...
# 3009  Київ, 15 березня 2024 року. Здавалося б, еколо...
# 3010  Відновлення Каховської ГЕС, зруйнованої влітку...
# 3011  В Україні розгорівся скандал навколо змін у си...
#
# [3012 rows x 2 columns]

# %%
df_2 = pd.read_csv(path_2)
df_2
# Out:
#       Unnamed: 0                                              title  \
# 0              0  МКІП підозрюють у зловживанні коштами, виділен...
# 1              1  Ситуація на Каховському водосховищі стабілізує...
# 2              2  Український культурний фонд переглянув стратег...
# 3              3  МОН розглядає можливість переходу на 11-річну ...
# 4              4  МОН планує ввести обов'язковий курс «Ефективне...
# ...          ...                                                ...
# 6144        6144  Київська кільцева: рік потому. Як обіцянки мін...
# 6145        6145  СБУ розслідує можливу змову між окремими депут...
# 6146        6146  МОЗ розширює програму психологічної підтримки ...
# 6147        6147  Укренерго успішно протестувало нову систему ро...
# 6148        6148  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text label
# 0     Міністерство культури та інформаційної політик...  Fake
# 1     Рівень води у Каховському водосховищі продовжу...  Fake
# 2     Український культурний фонд (УКФ) оголосив про...  Fake
# 3     Міністерство освіти і науки України розглядає ...  Fake
# 4     Міністерство освіти і науки України розглядає ...  Fake
# ...                                                 ...   ...
# 6144  Рік тому, у розпал дискусій про відновлення кр...  Fake
# 6145  Служба безпеки України відкрила кримінальне пр...  Fake
# 6146  Міністерство охорони здоров'я України оголосил...  Fake
# 6147  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...  Fake
# 6148  Міністерство культури та інформаційної політик...  Fake
#
# [6149 rows x 4 columns]

# %%
df_2["label"] = "Fake"

# %%
df_2 = df_2.drop("Unnamed: 0", axis=1)
df_2
# Out:
#                                                   title  \
# 0     МКІП підозрюють у зловживанні коштами, виділен...
# 1     Ситуація на Каховському водосховищі стабілізує...
# 2     Український культурний фонд переглянув стратег...
# 3     МОН розглядає можливість переходу на 11-річну ...
# 4     МОН планує ввести обов'язковий курс «Ефективне...
# ...                                                 ...
# 6144  Київська кільцева: рік потому. Як обіцянки мін...
# 6145  СБУ розслідує можливу змову між окремими депут...
# 6146  МОЗ розширює програму психологічної підтримки ...
# 6147  Укренерго успішно протестувало нову систему ро...
# 6148  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text label
# 0     Міністерство культури та інформаційної політик...  Fake
# 1     Рівень води у Каховському водосховищі продовжу...  Fake
# 2     Український культурний фонд (УКФ) оголосив про...  Fake
# 3     Міністерство освіти і науки України розглядає ...  Fake
# 4     Міністерство освіти і науки України розглядає ...  Fake
# ...                                                 ...   ...
# 6144  Рік тому, у розпал дискусій про відновлення кр...  Fake
# 6145  Служба безпеки України відкрила кримінальне пр...  Fake
# 6146  Міністерство охорони здоров'я України оголосил...  Fake
# 6147  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...  Fake
# 6148  Міністерство культури та інформаційної політик...  Fake
#
# [6149 rows x 3 columns]

# %%
df_combined = pd.concat(
    [df_1, df_2],
    ignore_index=True
)

df_combined["label"] = "Fake"

df_combined
# Out:
#                                                   title  \
# 0     Київ ризикує залишитись без води: "Київводокан...
# 1     Ексклюзив: МОН розглядає можливість запровадже...
# 2     Угорщина знову блокує допомогу Україні: Орбан ...
# 3     За крок до прірви: Угорщина блокує критично ва...
# 4     Медична реформа дала збій: на Київщині зафіксо...
# ...                                                 ...
# 9156  Київська кільцева: рік потому. Як обіцянки мін...
# 9157  СБУ розслідує можливу змову між окремими депут...
# 9158  МОЗ розширює програму психологічної підтримки ...
# 9159  Укренерго успішно протестувало нову систему ро...
# 9160  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text label
# 0     У Києві назріває масштабна криза водопостачанн...  Fake
# 1     Інформація про можливе запровадження обов'язко...  Fake
# 2     Будапешт знову став на заваді виділенню чергов...  Fake
# 3     Брюссель, Бельгія – На тлі загострення ситуаці...  Fake
# 4     На Київщині, у Васильківському районі, зафіксо...  Fake
# ...                                                 ...   ...
# 9156  Рік тому, у розпал дискусій про відновлення кр...  Fake
# 9157  Служба безпеки України відкрила кримінальне пр...  Fake
# 9158  Міністерство охорони здоров'я України оголосил...  Fake
# 9159  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...  Fake
# 9160  Міністерство культури та інформаційної політик...  Fake
#
# [9161 rows x 3 columns]

# %%
df_combined.to_csv("..//..//data//fake_news_dataset.csv")

# %%
df = pd.read_csv("..//..//data//fake_news_dataset.csv")
df
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Київ ризикує залишитись без води: "Київводокан...
# 1              1  Ексклюзив: МОН розглядає можливість запровадже...
# 2              2  Угорщина знову блокує допомогу Україні: Орбан ...
# 3              3  За крок до прірви: Угорщина блокує критично ва...
# 4              4  Медична реформа дала збій: на Київщині зафіксо...
# ...          ...                                                ...
# 9156        9156  Київська кільцева: рік потому. Як обіцянки мін...
# 9157        9157  СБУ розслідує можливу змову між окремими депут...
# 9158        9158  МОЗ розширює програму психологічної підтримки ...
# 9159        9159  Укренерго успішно протестувало нову систему ро...
# 9160        9160  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text label
# 0     У Києві назріває масштабна криза водопостачанн...  Fake
# 1     Інформація про можливе запровадження обов'язко...  Fake
# 2     Будапешт знову став на заваді виділенню чергов...  Fake
# 3     Брюссель, Бельгія – На тлі загострення ситуаці...  Fake
# 4     На Київщині, у Васильківському районі, зафіксо...  Fake
# ...                                                 ...   ...
# 9156  Рік тому, у розпал дискусій про відновлення кр...  Fake
# 9157  Служба безпеки України відкрила кримінальне пр...  Fake
# 9158  Міністерство охорони здоров'я України оголосил...  Fake
# 9159  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...  Fake
# 9160  Міністерство культури та інформаційної політик...  Fake
#
# [9161 rows x 4 columns]
