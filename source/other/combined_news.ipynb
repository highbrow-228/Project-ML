# %%
import pandas as pd

path_1 = "..//..//data//fake_news_dataset_2.csv"
path_2 = "..//..//data//fake_news_dataset.csv"

df_1 = pd.read_csv(path_1)
df_1
# Out:
#                                                   title  \
# 0     МКІП підозрюють у зловживанні коштами, виділен...
# 1     Ситуація на Каховському водосховищі стабілізує...
# 2     Український культурний фонд переглянув стратег...
# 3     МОН розглядає можливість переходу на 11-річну ...
# 4     МОН планує ввести обов'язковий курс «Ефективне...
# ...                                                 ...
# 4627  МКІП ініціює програму підтримки митців, які пр...
# 4628  Уряд розширює програму пільгового кредитування...
# 4629  МОЗ попереджає про нову хвилю «чорної віспи» с...
# 4630  Забруднення Каховського водосховища загрожує е...
# 4631  Київська ОВА ігнорує запити ТРО щодо укріплень...
#
#                                                    text
# 0     Міністерство культури та інформаційної політик...
# 1     Рівень води у Каховському водосховищі продовжу...
# 2     Український культурний фонд (УКФ) оголосив про...
# 3     Міністерство освіти і науки України розглядає ...
# 4     Міністерство освіти і науки України розглядає ...
# ...                                                 ...
# 4627  Міністерство культури та інформаційної політик...
# 4628  Кабінет Міністрів України ухвалив рішення про ...
# 4629  У Міністерстві охорони здоров'я б'ють на споло...
# 4630  Рівень забруднення Каховського водосховища кри...
# 4631  Тривожні сигнали надходять з Київщини. Предста...
#
# [4632 rows x 2 columns]

# %%
df_2 = pd.read_csv(path_2)
df_2
# Out:
#                                                   title  \
# 0     Ексклюзив: МОН розглядає можливість запровадже...
# 1     Уряд розширює програму пільгового кредитування...
# 2     Попри обстріли, в Києві відновлюють мозаїчне п...
# 3     Кабмін розглядає можливість перейменування Мін...
# 4     Угорщина заблокувала €8 млрд допомоги Україні,...
# ...                                                 ...
# 1512  Київська кільцева: рік потому. Як обіцянки мін...
# 1513  СБУ розслідує можливу змову між окремими депут...
# 1514  МОЗ розширює програму психологічної підтримки ...
# 1515  Укренерго успішно протестувало нову систему ро...
# 1516  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text
# 0     Міністерство освіти і науки України розглядає ...
# 1     Кабінет Міністрів України вніс зміни до програ...
# 2     Київ, 17 березня 2024 року. Роботи з відновлен...
# 3     У кулуарах уряду активно обговорюється ідея ре...
# 4     Будапешт знову ставить палки в колеса європейс...
# ...                                                 ...
# 1512  Рік тому, у розпал дискусій про відновлення кр...
# 1513  Служба безпеки України відкрила кримінальне пр...
# 1514  Міністерство охорони здоров'я України оголосил...
# 1515  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...
# 1516  Міністерство культури та інформаційної політик...
#
# [1517 rows x 2 columns]

# %%
df_combined = pd.concat(
    [df_1, df_2],
    ignore_index=True
)

df_combined["label"] = "Fake"

df_combined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_combined = pd.concat(
#       2     [df_1, df_2],
#       3     ignore_index=True
#       4 )
#       6 df_combined["label"] = "Fake"
#       8 df_combined
#
# NameError: name 'pd' is not defined

# %%
df_combined
# Out:
#                                                   title  \
# 0     МКІП підозрюють у зловживанні коштами, виділен...
# 1     Ситуація на Каховському водосховищі стабілізує...
# 2     Український культурний фонд переглянув стратег...
# 3     МОН розглядає можливість переходу на 11-річну ...
# 4     МОН планує ввести обов'язковий курс «Ефективне...
# ...                                                 ...
# 6144  Київська кільцева: рік потому. Як обіцянки мін...
# 6145  СБУ розслідує можливу змову між окремими депут...
# 6146  МОЗ розширює програму психологічної підтримки ...
# 6147  Укренерго успішно протестувало нову систему ро...
# 6148  Тривожні тенденції: Мінкульт ініціює перегляд ...
#
#                                                    text label
# 0     Міністерство культури та інформаційної політик...  Fake
# 1     Рівень води у Каховському водосховищі продовжу...  Fake
# 2     Український культурний фонд (УКФ) оголосив про...  Fake
# 3     Міністерство освіти і науки України розглядає ...  Fake
# 4     Міністерство освіти і науки України розглядає ...  Fake
# ...                                                 ...   ...
# 6144  Рік тому, у розпал дискусій про відновлення кр...  Fake
# 6145  Служба безпеки України відкрила кримінальне пр...  Fake
# 6146  Міністерство охорони здоров'я України оголосил...  Fake
# 6147  Київ, 17 жовтня 2024 року. НЕК «Укренерго» усп...  Fake
# 6148  Міністерство культури та інформаційної політик...  Fake
#
# [6149 rows x 3 columns]

# %%
df_combined.to_csv("..//..//data//fake_news_dataset.csv")
